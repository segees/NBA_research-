# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
import re

# %%
missed_EDA=pd.read_csv('C:\prject\missedgames_cleaned.csv',index_col = 0)
stats_EDA=pd.read_csv('C:\prject\player_stats_cleaned.csv',index_col = 0)
team_EDA=pd.read_csv(r'C:\prject\all_teams_schedule_2010_2020_cleaned.csv',index_col = 0)

# %%
missed_EDA
# Out:
#             Date                   Team              Player  \
# 0     2010-08-03   Los Angeles Clippers         Craig Smith
# 1     2010-08-13       Dallas Mavericks   Rodrigue Beaubois
# 2     2010-08-14  Golden State Warriors           Ekpe Udoh
# 3     2010-09-21        Toronto Raptors            Ed Davis
# 4     2010-09-21  Oklahoma City Thunder        Nenad Krstic
# ...          ...                    ...                 ...
# 9664  2020-08-23       Dallas Mavericks  Kristaps Porzingis
# 9665  2020-08-24  Oklahoma City Thunder       Deonte Burton
# 9666  2020-08-25     Los Angeles Lakers       Anthony Davis
# 9667  2020-08-25         Boston Celtics       Javonte Green
# 9668  2020-08-26        Toronto Raptors          Kyle Lowry
#
#                                                   Notes
# 0     arthroscopic surgery on right knee (out indefi...
# 1     surgery on left foot to repair fractured fifth...
# 2              surgery on left wrist (out indefinitely)
# 3     arthroscopic surgery on right kene to repair t...
# 4     surgery on right hand to repair broken finger ...
# ...                                                 ...
# 9664                              sore right knee (DTD)
# 9665                              stomach illness (DTD)
# 9666                                  back spasms (DTD)
# 9667  arthroscopic surgery on right knee to repair t...
# 9668                          sprained left ankle (DTD)
#
# [9669 rows x 4 columns]

# %%
pattern='\((.*)\)'
DNP=0
DTD=0
out_for_season=0
out_idefinitely=0
unknowen_absence=0
common_injury=['DNP','DTD','out for season','out indefinitely','unknowen absence']
for i in missed_EDA['Notes']:
    m=re.findall(pattern,i)
    if m:
        if m[0]==common_injury[0]:
            DNP+=1
        elif m[0]==common_injury[1]:
            DTD+=1
        elif m[0]==common_injury[2]:
            out_for_season+=1
        elif m[0]==common_injury[3]:
            out_idefinitely+=1
    else:
        unknowen_absence+=1
listt=[DNP,DTD,out_for_season,out_idefinitely,unknowen_absence]
plot_df=pd.DataFrame({'number of injuries':listt},index=common_injury)
plot_df
plot = plot_df.plot.pie(y='number of injuries', figsize=(6, 6))
plt.savefig('number_of_injuries.png', transparent = True)
plt.show()

# %%
plot_df
# Out:
#                   number of injuries
# DNP                             4586
# DTD                             3513
# out for season                   538
# out indefinitely                 588
# unknowen absence                 145

# %%
stats_EDA
# Out:
#       Year         Player Pos  Age                    Team   G  GS  MPPG  \
# 0     2010    Jeff Adrien  PF   24   Golden State Warriors  23   0   8.5
# 1     2010  Arron Afflalo  SG   25          Denver Nuggets  69  69  33.7
# 2     2010   Maurice Ager  SG   26  Minnesota Timberwolves   4   0   7.3
# 3     2010  Alexis Ajinca   C   22         Toronto Raptors  34   2  10.0
# 4     2010  Solomon Alabi   C   22         Toronto Raptors  12   0   4.9
# ...    ...            ...  ..  ...                     ...  ..  ..   ...
# 4927  2019     Trae Young  PG   21           Atlanta Hawks  60  60  35.3
# 4928  2019    Cody Zeller   C   27       Charlotte Hornets  58  39  23.1
# 4929  2019   Tyler Zeller   C   30       San Antonio Spurs   2   0   2.0
# 4930  2019     Ante Zizic   C   23     Cleveland Cavaliers  22   0  10.0
# 4931  2019    Ivica Zubac   C   22    Los Angeles Clippers  72  70  18.4
#
#        FGA  3PA   2PA  FTA  ORB  DRB  STL  BLK
# 0      2.3  0.0   2.3  0.8  1.0  1.5  0.2  0.2
# 1      9.1  3.6   5.5  2.4  0.7  3.0  0.5  0.4
# 2      2.8  1.0   1.8  0.0  0.0  0.5  0.3  0.0
# 3      3.9  1.0   2.9  0.5  0.5  1.8  0.3  0.6
# 4      1.3  0.0   1.3  0.2  0.6  0.6  0.2  0.2
# ...    ...  ...   ...  ...  ...  ...  ...  ...
# 4927  20.8  9.5  11.4  9.3  0.5  3.7  1.1  0.1
# 4928   8.3  1.3   7.0  3.1  2.8  4.3  0.7  0.4
# 4929   2.0  0.0   2.0  0.0  1.5  0.5  0.0  0.0
# 4930   3.3  0.0   3.3  0.9  0.8  2.2  0.3  0.2
# 4931   5.3  0.0   5.3  2.3  2.7  4.8  0.2  0.9
#
# [4932 rows x 16 columns]

# %%
df_stats_important =stats_EDA
indexNames = df_stats_important[ df_stats_important['MPPG'] < 20 ].index
df_stats_important.drop(indexNames , inplace=True)
df_stats_important.reset_index(drop=True, inplace=True)
df_stats_important
# Out:
#       Year             Player Pos  Age                   Team   G  GS  MPPG  \
# 0     2010      Arron Afflalo  SG   25         Denver Nuggets  69  69  33.7
# 1     2010  LaMarcus Aldridge  PF   25  Portland Trailblazers  81  81  39.6
# 2     2010          Ray Allen  SG   35         Boston Celtics  80  80  36.1
# 3     2010         Tony Allen  SG   29      Memphis Grizzlies  72  31  20.8
# 4     2010      Ryan Anderson  PF   22          Orlando Magic  64  14  22.3
# ...    ...                ...  ..  ...                    ...  ..  ..   ...
# 2399  2019     Christian Wood  PF   24        Detroit Pistons  62  12  21.4
# 2400  2019       Delon Wright  PG   27       Dallas Mavericks  73   5  21.5
# 2401  2019     Thaddeus Young  PF   31          Chicago Bulls  64  16  24.9
# 2402  2019         Trae Young  PG   21          Atlanta Hawks  60  60  35.3
# 2403  2019        Cody Zeller   C   27      Charlotte Hornets  58  39  23.1
#
#        FGA  3PA   2PA  FTA  ORB  DRB  STL  BLK
# 0      9.1  3.6   5.5  2.4  0.7  3.0  0.5  0.4
# 1     17.5  0.3  17.2  5.5  3.4  5.3  1.0  1.2
# 2     12.2  4.7   7.5  2.7  0.6  2.8  1.0  0.2
# 3      6.8  0.3   6.5  2.5  1.0  1.7  1.8  0.6
# 4      8.2  5.3   2.9  1.8  2.0  3.5  0.5  0.6
# ...    ...  ...   ...  ...  ...  ...  ...  ...
# 2399   8.2  2.3   5.9  3.9  1.7  4.6  0.5  0.9
# 2400   5.6  1.7   3.9  1.4  1.0  2.9  1.2  0.3
# 2401   9.4  3.5   5.9  1.1  1.5  3.5  1.4  0.4
# 2402  20.8  9.5  11.4  9.3  0.5  3.7  1.1  0.1
# 2403   8.3  1.3   7.0  3.1  2.8  4.3  0.7  0.4
#
# [2404 rows x 16 columns]

# %%
df_missed=missed_EDA.copy()
df_missed['Date'] = pd.DatetimeIndex(df_missed['Date']).year
df_missed.rename(columns={'Date':'Year'},inplace=True)
df_missed.reset_index(drop=True, inplace=True)
df_missed
# Out:
#       Year                   Team              Player  \
# 0     2010   Los Angeles Clippers         Craig Smith
# 1     2010       Dallas Mavericks   Rodrigue Beaubois
# 2     2010  Golden State Warriors           Ekpe Udoh
# 3     2010        Toronto Raptors            Ed Davis
# 4     2010  Oklahoma City Thunder        Nenad Krstic
# ...    ...                    ...                 ...
# 9664  2020       Dallas Mavericks  Kristaps Porzingis
# 9665  2020  Oklahoma City Thunder       Deonte Burton
# 9666  2020     Los Angeles Lakers       Anthony Davis
# 9667  2020         Boston Celtics       Javonte Green
# 9668  2020        Toronto Raptors          Kyle Lowry
#
#                                                   Notes
# 0     arthroscopic surgery on right knee (out indefi...
# 1     surgery on left foot to repair fractured fifth...
# 2              surgery on left wrist (out indefinitely)
# 3     arthroscopic surgery on right kene to repair t...
# 4     surgery on right hand to repair broken finger ...
# ...                                                 ...
# 9664                              sore right knee (DTD)
# 9665                              stomach illness (DTD)
# 9666                                  back spasms (DTD)
# 9667  arthroscopic surgery on right knee to repair t...
# 9668                          sprained left ankle (DTD)
#
# [9669 rows x 4 columns]

# %%
df = df_stats_important.merge(df_missed, on=['Player','Team','Year'], how='left')
df.to_csv(r'C:\prject\before_important_missedgames_cleaned.csv')
df.dropna(how='any',inplace=True)
df.reset_index(drop=True, inplace=True)
df.to_csv(r'C:\prject\important_missedgames_cleaned.csv')
df.Year.hist(bins=10, grid = False, rwidth=0.7)
plt.xlabel('Years')
plt.ylabel('Amount')
plt.title('injuries per year')
plt.savefig('injuries_per_year.png', transparent = True)
plt.show()

# %%
df.drop_duplicates(subset=['Player','Year'],keep='first',inplace=True)
df.reset_index(drop=True, inplace=True)
df
# Out:
#       Year            Player Pos  Age                    Team   G  GS  MPPG  \
# 0     2010     Ryan Anderson  PF   22           Orlando Magic  64  14  22.3
# 1     2010   Andrea Bargnani   C   25         Toronto Raptors  66  66  35.7
# 2     2010     Nicolas Batum  SF   22   Portland Trailblazers  80  67  31.5
# 3     2010    Jerryd Bayless  PG   22         Toronto Raptors  71  14  21.1
# 4     2010   Michael Beasley  SF   22  Minnesota Timberwolves  73  73  32.3
# ...    ...               ...  ..  ...                     ...  ..  ..   ...
# 1208  2019  Kenrich Williams  PF   25    New Orleans Pelicans  39  18  21.3
# 1209  2019   Zion Williamson  PF   19    New Orleans Pelicans  24  24  27.8
# 1210  2019   Justise Winslow  SG   23              Miami Heat  11   5  32.0
# 1211  2019    Christian Wood  PF   24         Detroit Pistons  62  12  21.4
# 1212  2019       Cody Zeller   C   27       Charlotte Hornets  58  39  23.1
#
#        FGA  3PA   2PA  FTA  ORB  DRB  STL  BLK  \
# 0      8.2  5.3   2.9  1.8  2.0  3.5  0.5  0.6
# 1     17.8  3.4  14.4  5.3  1.1  4.1  0.5  0.7
# 2     10.1  4.3   5.8  2.1  1.4  3.2  0.9  0.6
# 3      7.3  2.1   5.2  2.9  0.4  2.0  0.5  0.1
# 4     17.1  2.2  14.8  4.0  1.6  4.0  0.7  0.7
# ...    ...  ...   ...  ...  ...  ...  ...  ...
# 1208   3.8  2.5   1.3  0.7  1.3  3.5  0.7  0.5
# 1209  15.0  0.6  14.4  7.4  2.7  3.6  0.7  0.4
# 1210  11.7  2.5   9.3  2.5  1.5  5.2  0.6  0.5
# 1211   8.2  2.3   5.9  3.9  1.7  4.6  0.5  0.9
# 1212   8.3  1.3   7.0  3.1  2.8  4.3  0.7  0.4
#
#                                                Notes
# 0                          sprained right foot (DNP)
# 1                               sore left knee (DNP)
# 2                          sore right shoulder (DNP)
# 3                               food poisoning (DNP)
# 4                         sprained right ankle (DNP)
# ...                                              ...
# 1208                       sprained left ankle (DTD)
# 1209  torn meniscus in right knee (out indefinitely)
# 1210                               back injury (DTD)
# 1211                          left knee injury (DTD)
# 1212         fractured right hand (out indefinitely)
#
# [1213 rows x 17 columns]

# %%
missed_EDA

# %%
team_EDA

# %%
df_game_number = team_EDA.merge(missed_EDA, on=['Team','Date'], how='left')
df_game_number.dropna(how='any',inplace=True)
df_game_number.reset_index(drop=True, inplace=True)
df_game_number.to_csv(r'C:\prject\df_game_number.csv')
df_game_number.Game_num.hist(bins=82, grid = False, rwidth=0.7)
plt.xlabel('Game Number')
plt.ylabel('Amount of injuris')
plt.title('Most common game players get injured')
plt.savefig('common_game_injury.png', transparent = True)
plt.show()

# %%
df1 = pd.DataFrame([[np.nan] * len(df.columns)], columns=df.columns)
df = df1.append(df, ignore_index=True)
df
# Out:
#         Year            Player  Pos   Age                   Team     G    GS  \
# 0        NaN               NaN  NaN   NaN                    NaN   NaN   NaN
# 1     2010.0     Ryan Anderson   PF  22.0          Orlando Magic  64.0  14.0
# 2     2010.0   Andrea Bargnani    C  25.0        Toronto Raptors  66.0  66.0
# 3     2010.0     Nicolas Batum   SF  22.0  Portland Trailblazers  80.0  67.0
# 4     2010.0    Jerryd Bayless   PG  22.0        Toronto Raptors  71.0  14.0
# ...      ...               ...  ...   ...                    ...   ...   ...
# 1209  2019.0  Kenrich Williams   PF  25.0   New Orleans Pelicans  39.0  18.0
# 1210  2019.0   Zion Williamson   PF  19.0   New Orleans Pelicans  24.0  24.0
# 1211  2019.0   Justise Winslow   SG  23.0             Miami Heat  11.0   5.0
# 1212  2019.0    Christian Wood   PF  24.0        Detroit Pistons  62.0  12.0
# 1213  2019.0       Cody Zeller    C  27.0      Charlotte Hornets  58.0  39.0
#
#       MPPG   FGA  3PA   2PA  FTA  ORB  DRB  STL  BLK  \
# 0      NaN   NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 1     22.3   8.2  5.3   2.9  1.8  2.0  3.5  0.5  0.6
# 2     35.7  17.8  3.4  14.4  5.3  1.1  4.1  0.5  0.7
# 3     31.5  10.1  4.3   5.8  2.1  1.4  3.2  0.9  0.6
# 4     21.1   7.3  2.1   5.2  2.9  0.4  2.0  0.5  0.1
# ...    ...   ...  ...   ...  ...  ...  ...  ...  ...
# 1209  21.3   3.8  2.5   1.3  0.7  1.3  3.5  0.7  0.5
# 1210  27.8  15.0  0.6  14.4  7.4  2.7  3.6  0.7  0.4
# 1211  32.0  11.7  2.5   9.3  2.5  1.5  5.2  0.6  0.5
# 1212  21.4   8.2  2.3   5.9  3.9  1.7  4.6  0.5  0.9
# 1213  23.1   8.3  1.3   7.0  3.1  2.8  4.3  0.7  0.4
#
#                                                Notes
# 0                                                NaN
# 1                          sprained right foot (DNP)
# 2                               sore left knee (DNP)
# 3                          sore right shoulder (DNP)
# 4                               food poisoning (DNP)
# ...                                              ...
# 1209                       sprained left ankle (DTD)
# 1210  torn meniscus in right knee (out indefinitely)
# 1211                               back injury (DTD)
# 1212                          left knee injury (DTD)
# 1213         fractured right hand (out indefinitely)
#
# [1214 rows x 17 columns]

# %%
df_dummy=df.copy()
df_dummy['Year'].iloc[0]=2020
df_dummy.sort_values(by=['Year'],inplace=True,ignore_index=True)
# Out:
# C:\Users\segev\anaconda3\lib\site-packages\pandas\core\indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_dummy
# Out:
#         Year          Player  Pos   Age                  Team     G    GS  \
# 0     2010.0    John Salmons   SG  31.0       Milwaukee Bucks  73.0  70.0
# 1     2010.0   Udonis Haslem   PF  30.0            Miami Heat  13.0   0.0
# 2     2010.0     Chuck Hayes    C  27.0       Houston Rockets  74.0  63.0
# 3     2010.0            Nene    C  28.0        Denver Nuggets  75.0  75.0
# 4     2010.0     George Hill   PG  24.0     San Antonio Spurs  76.0   5.0
# ...      ...             ...  ...   ...                   ...   ...   ...
# 1209  2019.0     Joel Embiid    C  25.0    Philadelphia 76ers  51.0  51.0
# 1210  2019.0       Kris Dunn   PG  25.0         Chicago Bulls  51.0  32.0
# 1211  2019.0    Goran Dragic   PG  33.0            Miami Heat  59.0   3.0
# 1212  2019.0  JaMychal Green   PF  29.0  Los Angeles Clippers  63.0   1.0
# 1213  2020.0             NaN  NaN   NaN                   NaN   NaN   NaN
#
#       MPPG   FGA  3PA   2PA  FTA  ORB  DRB  STL  BLK  \
# 0     35.0  12.3  3.0   9.3  3.3  0.4  3.3  1.0  0.4
# 1     26.5   6.6  0.0   6.6  1.5  2.2  5.9  0.5  0.2
# 2     28.1   6.3  0.0   6.2  1.9  3.0  5.1  1.1  0.7
# 3     30.5   8.7  0.1   8.7  5.4  1.9  5.7  1.1  1.0
# 4     28.3   8.3  2.7   5.6  3.6  0.3  2.3  0.9  0.3
# ...    ...   ...  ...   ...  ...  ...  ...  ...  ...
# 1209  29.5  15.7  3.4  12.3  8.5  2.8  8.9  0.9  1.3
# 1210  24.9   6.7  2.2   4.5  1.1  0.5  3.2  2.0  0.3
# 1211  28.2  12.3  5.7   6.5  4.2  0.5  2.7  0.7  0.2
# 1212  20.7   5.6  3.8   1.8  0.8  1.2  4.9  0.5  0.4
# 1213   NaN   NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
#
#                                                   Notes
# 0                                     back spasms (DNP)
# 1     surgery on left foot to repair torn ligament (...
# 2               sprained right ankle (out indefinitely)
# 3                             strained left groin (DNP)
# 4                          sprained right big toe (DNP)
# ...                                                 ...
# 1209                               sore left knee (DTD)
# 1210                     strained back (out for season)
# 1211                           strained left calf (DTD)
# 1212                              tailbone injury (DTD)
# 1213                                                NaN
#
# [1214 rows x 17 columns]

# %%
PF=[]
C=[]
SF=[]
PG=[]
SG=[]
PF_len=0
C_len=0
SF_len=0
PG_len=0
SG_len=0
index = range(2010,2020)
for i in range(0,len(df_dummy)-1):
    if df_dummy['Pos'].iloc[i]=='PF':
        PF_len+=1
    if df_dummy['Pos'].iloc[i]=='C':
        C_len+=1
    if df_dummy['Pos'].iloc[i]=='SF':
        SF_len+=1
    if df_dummy['Pos'].iloc[i]=='PG':
        PG_len+=1
    if df_dummy['Pos'].iloc[i]=='SG':
        SG_len+=1
    if df_dummy['Year'].iloc[i]!=df_dummy['Year'].iloc[i+1]:
        PF.append(PF_len)
        C.append(C_len)
        SF.append(SF_len)
        PG.append(PG_len)
        SG.append(SG_len)
        PF_len=0
        C_len=0
        SF_len=0
        PG_len=0
        SG_len=0

# %%
dfgff = pd.DataFrame({'PF': PF,
                   'C': C,
                     'SF': SF,
                     'PG': PG,
                     'SG': SG,}, index=index)
dfgff
# Out:
#       PF   C  SF  PG  SG
# 2010  11  16  10  11  16
# 2011  21  14  22  18  21
# 2012  27  21  26  24  32
# 2013  29  19  21  31  26
# 2014  24  22  20  23  34
# 2015  26  28  30  32  32
# 2016  24  22  31  32  39
# 2017  28  28  20  30  33
# 2018  21  24  17  25  35
# 2019  27  21  15  23  31

# %%
ax = dfgff.plot.bar(rot=0)
